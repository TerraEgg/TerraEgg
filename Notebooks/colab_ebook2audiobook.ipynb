# %% [markdown]
# <a href="https://colab.research.google.com/github/TerraEgg/TerraEgg/blob/main/Notebooks/colab_ebook2audiobook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Welcome to the ebook2audiobook Google Colab!
# ## Features
# - 🔧 **TTS Engines supported**: XTTSv2, Bark, Fairseq, VITS, Tacotron2, Tortoise, GlowTTS, YourTTS- 📚 **Convert multiple file formats**: .epub, .mobi, .azw3, .fb2, .lrf, .rb, .snb, .tcr, .pdf, .txt, .rtf, .doc, .docx, .html, .odt, .azw, .tiff, .tif, .png, .jpg, .jpeg, .bmp
# - 🔍 **OCR scanning** for files with text pages as images
# - 🔊 **High-quality text-to-speech** from near realtime to near real voice
# - 🗣️ **Optional voice cloning** using your own voice file
# - 🌐 **Supports 1158 languages** ([supported languages list](https://dl.fbaipublicfiles.com/mms/tts/all-tts-languages.html))
# - 💻 **Low-resource friendly** — runs on **2 GB RAM / 1 GB VRAM (minimum)**
# - 🎵 **Audiobook output formats**: mono or stereo aac, flac, mp3, m4b, m4a, mp4, mov, ogg, wav, webm
# - 🧠 **SML tags supported** — fine-grained control of breaks, pauses, voice switching and more ([see below](#sml-tags-available))
# - 🧩 **Optional custom model** using your own trained model (XTTSv2 only, other on request)
# - 🎛️ **Fine-tuned preset models** trained by the E2A Team<br/>
#      <i>(Contact us if you need additional fine-tuned models, or if you'd like to share yours to the official preset list)</i>## Want to run locally for free? ⬇
# ## [Check out the ebook2audiobook github!](https://github.com/DrewThomasson/ebook2audiobook)

# %%
# @title 🚀 Run ebook2audiobook!

import os
import subprocess
import time
import shutil
import sysconfig

# Emojis for logs
CHECK_MARK = "✅"
CROSS_MARK = "❌"

SCRIPT_DIR = "/content/ebook2audiobook"

# ── Environment variables (mirrors the bash script) ──────────────────────────
os.environ["PYTHONUTF8"]        = "1"
os.environ["PYTHONIOENCODING"]  = "utf-8"
os.environ["TTS_CACHE"]         = f"{SCRIPT_DIR}/models"
os.environ["TESSDATA_PREFIX"]   = f"{SCRIPT_DIR}/models/tessdata"
os.environ["TMPDIR"]            = f"{SCRIPT_DIR}/tmp"

def display_loading_bar(total_steps):
    print("\n---  LOADING...  Total steps:", total_steps, " ---")

def update_progress(step, total_steps):
    bar_length = 20
    progress_percent = int((step / total_steps) * 100)
    progress_filled = int(bar_length * step / total_steps)
    bar = '=' * progress_filled + '>' + ' ' * max(bar_length - progress_filled - 1, 0)
    print(f"---  PROGRESS:  [{bar}] {progress_percent}% ({step}/{total_steps}) ---")

def run_command_with_log(command, description, step_progress, total_step_commands):
    """Runs a shell command and logs progress, outcome and duration."""
    print(f"\n{step_progress}/{total_step_commands}: {description}...")
    start_time = time.time()
    try:
        process = subprocess.Popen(command, shell=True,
                                   stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        stdout, stderr = process.communicate()
        duration = f"{time.time() - start_time:.2f}"
        if process.returncode != 0:
            print(f"{CROSS_MARK} Command failed: {description} (Took {duration}s)")
            print(f"   Command: {command}")
            print(f"   Error Output:\n{stderr.decode()}")
            return False
        else:
            update_progress(step_progress, total_step_commands)
            print(f"{CHECK_MARK} {step_progress}/{total_step_commands} completed: {description} (Took {duration}s)")
            return True
    except Exception as e:
        duration = f"{time.time() - start_time:.2f}"
        print(f"{CROSS_MARK} Error during: {description} (Took {duration}s) — {e}")
        return False


# ── Step 1 : OS-level packages ────────────────────────────────────────────────
# Mirrors HOST_PROGRAMS from the bash script + Calibre's special installer
os_install_commands = [
    ("apt-get update -qq",
     "Update package lists"),
    ("apt-get install -y -qq libxcb-cursor0 libegl1 libopengl0",
     "Install Calibre display libraries (libxcb-cursor0, libegl1, libopengl0)"),
    ("sudo -v && wget -nv -O- https://download.calibre-ebook.com/linux-installer.sh | sudo sh /dev/stdin",
     "Download & install Calibre"),
    ("apt-get install -y -qq ffmpeg",
     "Install ffmpeg"),
    ("apt-get install -y -qq mediainfo",
     "Install mediainfo"),
    ("apt-get install -y -qq nodejs",
     "Install nodejs"),
    ("apt-get install -y -qq espeak-ng",
     "Install espeak-ng"),
    ("apt-get install -y -qq sox",
     "Install sox"),
    ("apt-get install -y -qq tesseract-ocr tesseract-ocr-eng",
     "Install Tesseract OCR + English language pack"),
    # mecab + unidic (for Japanese support, same as old notebook)
    ("apt-get install -y -qq mecab libmecab-dev mecab-ipadic-utf8",
     "Install mecab (Japanese text analysis)"),
    # Rust is required by some pip packages (e.g. tokenizers)
    ("curl -fsSL https://sh.rustup.rs | sh -s -- -y --quiet && "
     "echo 'source $HOME/.cargo/env' >> ~/.bashrc",
     "Install Rust (required by some Python packages)"),
]

# ── Step 2 : Git clone ────────────────────────────────────────────────────────
git_commands = [
    ("git clone --depth=1 https://github.com/DrewThomasson/ebook2audiobook.git /content/ebook2audiobook",
     "Git clone ebook2audiobook"),
]

# ── Step 3 : Python packages  (mirrors install_python_packages()) ─────────────
# llvmlite/numba must be installed first as pre-built binaries;
# then the rest of requirements.txt is installed line-by-line.
# unidic download closes out the step.
pip_commands = [
    ("pip install -q --upgrade pip setuptools wheel",
     "Upgrade pip / setuptools / wheel"),
    ("pip install -q --upgrade llvmlite numba --only-binary=:all:",
     "Install llvmlite & numba (pre-built binaries only)"),
    ("pip install -q --upgrade --no-cache-dir "
     "-r /content/ebook2audiobook/requirements.txt",
     "Install Python requirements from requirements.txt"),
    ("python -m unidic download",
     "Download Unidic dictionary data"),
]


# ── Helper: sitecustomize hook (mirrors check_sitecustomized()) ───────────────
def install_sitecustomize():
    src = f"{SCRIPT_DIR}/components/sitecustomize.py"
    dst_dir = sysconfig.get_paths()["purelib"]
    dst = os.path.join(dst_dir, "sitecustomize.py")
    if not os.path.exists(src):
        print(f"{CROSS_MARK} sitecustomize.py source not found at {src}, skipping.")
        return False
    if not os.path.exists(dst) or os.path.getmtime(src) > os.path.getmtime(dst):
        shutil.copy2(src, dst)
        print(f"{CHECK_MARK} Installed sitecustomize.py hook → {dst}")
    else:
        print(f"{CHECK_MARK} sitecustomize.py already up-to-date.")
    return True


# ════════════════════════════════════════════════════════════════════════════
# EXECUTION
# ════════════════════════════════════════════════════════════════════════════

# --- Step 1: OS packages ---
print("\n--- Step 1: OS-Level Installations ---")
print("Installs system packages required by the bash script. (~3-5 min)")
display_loading_bar(len(os_install_commands))
step1_ok = True
for i, (cmd, desc) in enumerate(os_install_commands):
    if not run_command_with_log(cmd, desc, i + 1, len(os_install_commands)):
        step1_ok = False
        break

# Activate Rust for the current session after installation
cargo_env = os.path.expanduser("~/.cargo/env")
if os.path.exists(cargo_env):
    os.environ["PATH"] = os.path.expanduser("~/.cargo/bin") + ":" + os.environ.get("PATH", "")

if step1_ok:
    print(f"\n{CHECK_MARK} Step 1: OS-Level Installations — Completed Successfully!")
else:
    print(f"\n{CROSS_MARK} Step 1: OS-Level Installations — Failed. See errors above.")


# --- Step 2: Git Clone ---
print("\n--- Step 2: Git Clone ---")
display_loading_bar(len(git_commands))
step2_ok = True
for i, (cmd, desc) in enumerate(git_commands):
    if not run_command_with_log(cmd, desc, i + 1, len(git_commands)):
        step2_ok = False
        break

if step2_ok:
    print(f"\n{CHECK_MARK} Step 2: Git Clone — Completed Successfully!")
else:
    print(f"\n{CROSS_MARK} Step 2: Git Clone — Failed. See errors above.")


# --- Step 3: Python packages ---
print("\n--- Step 3: Python Package Installation ---")
print("Mirrors install_python_packages() from the bash script. (~3-5 min)")
display_loading_bar(len(pip_commands))
step3_ok = True
for i, (cmd, desc) in enumerate(pip_commands):
    if not run_command_with_log(cmd, desc, i + 1, len(pip_commands)):
        step3_ok = False
        break

if step3_ok:
    print(f"\n{CHECK_MARK} Step 3: Python Package Installation — Completed Successfully!")
else:
    print(f"\n{CROSS_MARK} Step 3: Python Package Installation — Failed. See errors above.")


# --- Step 4: sitecustomize hook ---
print("\n--- Step 4: Installing sitecustomize.py hook ---")
install_sitecustomize()


# --- Step 5: Create required directories ---
print("\n--- Step 5: Creating required directories ---")
for d in ["models", "models/tessdata", "tmp", "audiobooks", "ebooks", "voices"]:
    os.makedirs(f"{SCRIPT_DIR}/{d}", exist_ok=True)
os.chmod(f"{SCRIPT_DIR}/tmp", 0o777)
print(f"{CHECK_MARK} Directories ready.")


# --- Step 6: Run App ---
print("\n--- Step 6: Launch ebook2audiobook ---")
print("Starting the Gradio web interface with a public share link...")
try:
    # script_mode=native matches the NATIVE branch of the bash script;
    # --share creates the public Gradio tunnel link.
    get_ipython().system(
        "cd /content/ebook2audiobook && "
        "python app.py --script_mode native --share"
    )
except Exception as e:
    print(f"{CROSS_MARK} Error starting app.py: {e}")

print("\n--- All Steps Completed ---")
print("Check the output above for the public Gradio URL.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio==5.49.1) (3.11)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio==5.49.1) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio==5.49.1) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==5.49.1) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==5.49.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio==5.49.1) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio==5.49.1) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio==5.49.1) (1.4.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio==5.49.1) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.49.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.49.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.49.1) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio==5.49.1) (0.7.0)
# Collecting pydantic-core==2.33.2 (from pydantic<2.12,>=2.0->gradio==5.49.1)
#   Downloading pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.49.1) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.49.1) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.49.1) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio==5.49.1) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio==5.49.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio==5.49.1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio==5.49.1) (0.1.2)
# Downloading gradio-5.49.1-py3-none-any.whl (63.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 MB 32.3 MB/s  0:00:01
# Downloading gradio_client-1.13.3-py3-none-any.whl (325 kB)
# Downloading pydantic-2.11.10-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 37.9 MB/s  0:00:00
# Installing collected packages: pydantic-core, pydantic, gradio-client, gradio
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.4
#     Uninstalling pydantic_core-2.41.4:
#       Successfully uninstalled pydantic_core-2.41.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.3
#     Uninstalling pydantic-2.12.3:
#       Successfully uninstalled pydantic-2.12.3
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 1.14.0
#     Uninstalling gradio_client-1.14.0:
#       Successfully uninstalled gradio_client-1.14.0
#   Attempting uninstall: gradio
#     Found existing installation: gradio 5.50.0
#     Uninstalling gradio-5.50.0:
#       Successfully uninstalled gradio-5.50.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [gradio]
# Successfully installed gradio-5.49.1 gradio-client-1.13.3 pydantic-2.11.10 pydantic-core-2.33.2
# Collecting transformers==4.57.6
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (3.25.2)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers==4.57.6)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.6) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.6) (1.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.6) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.6) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.6) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.6) (2026.2.25)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 31.7 MB/s  0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 194.6 MB/s  0:00:00
# Installing collected packages: huggingface-hub, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.6.0
#     Uninstalling huggingface_hub-1.6.0:
#       Successfully uninstalled huggingface_hub-1.6.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [transformers]
# Successfully installed huggingface-hub-0.36.2 transformers-4.57.6
# Collecting coqui-tts==0.27.5 (from coqui-tts[languages]==0.27.5)
#   Downloading coqui_tts-0.27.5-py3-none-any.whl.metadata (21 kB)
# Collecting anyascii>=0.3.0 (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5)
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting coqpit-config<0.3.0,>=0.2.0 (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5)
#   Downloading coqpit_config-0.2.4-py3-none-any.whl.metadata (11 kB)
# Collecting coqui-tts-trainer<0.4.0,>=0.3.0 (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5)
#   Downloading coqui_tts_trainer-0.3.3-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.8.2)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (2025.3.0)
# Requirement already satisfied: inflect>=5.6.0 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (7.5.0)
# Collecting ko-speech-tools>=0.1.0 (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5)
#   Downloading ko_speech_tools-0.1.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: librosa>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.11.0)
# Requirement already satisfied: matplotlib>=3.8.4 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.10.0)
# Collecting monotonic-alignment-search>=0.1.0 (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5)
#   Downloading monotonic_alignment_search-0.2.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# Collecting num2words>=0.5.14 (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5)
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numba>=0.58.0 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.64.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (2.0.2)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (26.0)
# Collecting pysbd>=0.3.4 (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5)
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (6.0.3)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.16.3)
# Requirement already satisfied: soundfile>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.13.1)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (4.67.3)
# Requirement already satisfied: transformers>=4.57 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (4.57.6)
# Requirement already satisfied: typing-extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (4.15.0)
# Collecting bangla>=0.0.2 (from coqui-tts[languages]==0.27.5)
#   Downloading bangla-0.0.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting bnnumerizer>=0.0.2 (from coqui-tts[languages]==0.27.5)
#   Downloading bnnumerizer-0.0.2.tar.gz (4.7 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting bnunicodenormalizer>=0.1.0 (from coqui-tts[languages]==0.27.5)
#   Downloading bnunicodenormalizer-0.1.7-py3-none-any.whl.metadata (22 kB)
# Collecting cutlet>=0.2.0 (from coqui-tts[languages]==0.27.5)
#   Downloading cutlet-0.5.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting fugashi>=1.3.0 (from fugashi[unidic-lite]>=1.3.0; extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading fugashi-1.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.3 kB)
# Collecting gruut>=2.4.0 (from gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading gruut-2.4.0.tar.gz (85 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pypinyin>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from coqui-tts[languages]==0.27.5) (0.55.0)
# Collecting spacy-pkuseg>=1.0.1 (from coqui-tts[languages]==0.27.5)
#   Downloading spacy_pkuseg-1.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting uroman>=1.3.1.1 (from coqui-tts[languages]==0.27.5)
#   Downloading uroman-1.3.1.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (5.9.5)
# Requirement already satisfied: tensorboard>=2.17.1 in /usr/local/lib/python3.12/dist-packages (from coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (2.19.0)
# Collecting jaconv (from cutlet>=0.2.0->coqui-tts[languages]==0.27.5)
#   Downloading jaconv-0.5.0-py3-none-any.whl.metadata (8.9 kB)
# Collecting mojimoji (from cutlet>=0.2.0->coqui-tts[languages]==0.27.5)
#   Downloading mojimoji-0.0.13-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.13.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.23.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.11)
# Collecting unidic-lite (from fugashi[unidic-lite]>=1.3.0; extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading unidic-lite-1.0.8.tar.gz (47.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 241.7 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5) (2.18.0)
# Collecting dateparser~=1.1.1 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl.metadata (27 kB)
# Collecting gruut-ipa<1.0,>=0.12.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading gruut-ipa-0.13.0.tar.gz (101 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gruut_lang_en~=2.0.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading gruut_lang_en-2.0.1.tar.gz (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 211.4 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jsonlines~=1.2.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading jsonlines-1.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: networkx>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5) (3.6.1)
# Collecting python-crfsuite~=0.9.7 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5) (2.9.0.post0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5) (2025.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.12/dist-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5) (2025.11.3)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.12/dist-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5) (5.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from jsonlines~=1.2.0->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5) (1.17.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from num2words>=0.5.14->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.6.2)
# Collecting gruut_lang_de~=2.0.0 (from gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading gruut_lang_de-2.0.1.tar.gz (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 203.8 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gruut_lang_es~=2.0.0 (from gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading gruut_lang_es-2.0.1.tar.gz (31.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 217.6 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gruut_lang_fr~=2.0.0 (from gruut[de,es,fr]>=2.4.0; extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading gruut_lang_fr-2.0.2.tar.gz (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 219.1 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.12/dist-packages (from inflect>=5.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (10.8.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from inflect>=5.6.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (4.5.1)
# Collecting mecab-ko>=1.0.2 (from ko-speech-tools[g2p]>=0.1.0; python_version < "3.14" and extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading mecab_ko-1.0.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.1.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.4->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.4->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.4->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.4->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.4->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.4->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.3.2)
# Collecting mecab-ko-dic<2.0,>=1.0 (from mecab-ko>=1.0.2->ko-speech-tools[g2p]>=0.1.0; python_version < "3.14" and extra == "languages"->coqui-tts[languages]==0.27.5)
#   Downloading mecab-ko-dic-1.0.0.tar.gz (33.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.2/33.2 MB 200.4 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.58.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (4.9.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa>=0.11.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy-pkuseg>=1.0.1->coqui-tts[languages]==0.27.5) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from srsly<3.0.0,>=2.3.0->spacy-pkuseg>=1.0.1->coqui-tts[languages]==0.27.5) (2.0.10)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (5.29.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (82.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.1.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.25.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.36.2)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.57->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (1.4.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.0.3)
# Downloading coqui_tts-0.27.5-py3-none-any.whl (862 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.8/862.8 kB 586.1 MB/s  0:00:00
# Downloading coqpit_config-0.2.4-py3-none-any.whl (14 kB)
# Downloading coqui_tts_trainer-0.3.3-py3-none-any.whl (56 kB)
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
# Downloading bangla-0.0.5-py3-none-any.whl (5.1 kB)
# Downloading bnunicodenormalizer-0.1.7-py3-none-any.whl (23 kB)
# Downloading cutlet-0.5.0-py3-none-any.whl (11 kB)
# Downloading fugashi-1.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (694 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 694.9/694.9 kB 568.8 MB/s  0:00:00
# Downloading dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
# Downloading jsonlines-1.2.0-py2.py3-none-any.whl (7.6 kB)
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
# Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 346.3 MB/s  0:00:00
# Downloading ko_speech_tools-0.1.0-py3-none-any.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.3/997.3 kB 411.3 MB/s  0:00:00
# Downloading mecab_ko-1.0.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (592 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.0/593.0 kB 826.4 MB/s  0:00:00
# Downloading monotonic_alignment_search-0.2.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (648 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.4/648.4 kB 787.4 MB/s  0:00:00
# Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
# Downloading spacy_pkuseg-1.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 661.3 MB/s  0:00:00
# Downloading uroman-1.3.1.1-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.7/930.7 kB 634.8 MB/s  0:00:00
# Downloading jaconv-0.5.0-py3-none-any.whl (16 kB)
# Downloading mojimoji-0.0.13-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (211 kB)
# Building wheels for collected packages: bnnumerizer, gruut, gruut-ipa, gruut_lang_en, gruut_lang_de, gruut_lang_es, gruut_lang_fr, mecab-ko-dic, unidic-lite
#   Building wheel for bnnumerizer (pyproject.toml) ... done
#   Created wheel for bnnumerizer: filename=bnnumerizer-0.0.2-py3-none-any.whl size=5339 sha256=253616367a7c167a1944cb9bda873620bcd02274a64ad3a9fab7ff87328b1dc2
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-q17dk0qe/wheels/54/a3/40/cc330c64cd0abbaf0e112d9a14ae0b835c74f560b493ecc1bb
#   Building wheel for gruut (pyproject.toml) ... done
#   Created wheel for gruut: filename=gruut-2.4.0-py3-none-any.whl size=86855 sha256=c3ea350d955dfc1d7c8c92730c5818222f75d3d578a434bd618e8ef2ee716aa2
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-q17dk0qe/wheels/e6/93/9c/fbd0d8778ac586a48a20e73d2a64d882984d9501fd5e8daf24
#   Building wheel for gruut-ipa (pyproject.toml) ... done
#   Created wheel for gruut-ipa: filename=gruut_ipa-0.13.0-py3-none-any.whl size=104963 sha256=6f3dc8794303aa062212a099a0a9069de74aadc5ab28cb00d7942ffeb17f7ddc
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-q17dk0qe/wheels/66/9d/d2/d6f6eb77784f063fcd497427fd93324cebf974247984bba85b
#   Building wheel for gruut_lang_en (pyproject.toml) ... done
#   Created wheel for gruut_lang_en: filename=gruut_lang_en-2.0.1-py3-none-any.whl size=15326899 sha256=b5b8b5500b95eef7bfa88aa3e54b73cfa50d2d07b10d852db974bd0d2b01d495
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-q17dk0qe/wheels/b0/ca/a4/d1a6f20e47b857313689ca1f31684102ba67cecda2acae368d
#   Building wheel for gruut_lang_de (pyproject.toml) ... done
#   Created wheel for gruut_lang_de: filename=gruut_lang_de-2.0.1-py3-none-any.whl size=18498356 sha256=48b1918de856503368b465c7dc6b6a43991dc756cae32ab281a849a64a973d35
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-q17dk0qe/wheels/dc/75/26/e627d52dac0253ad7d11e5b9f74d51d82e040d07432f53ad9b
#   Building wheel for gruut_lang_es (pyproject.toml) ... done
#   Created wheel for gruut_lang_es: filename=gruut_lang_es-2.0.1-py3-none-any.whl size=32173970 sha256=09b766d84ac12afe7525d0e39755236ab63bac2ecebe49971f5b0924a26709ef
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-q17dk0qe/wheels/6e/19/79/0a65f77c4921ae0daa8d01e5b11502a909b55bd22fa188962d
#   Building wheel for gruut_lang_fr (pyproject.toml) ... done
#   Created wheel for gruut_lang_fr: filename=gruut_lang_fr-2.0.2-py3-none-any.whl size=10968810 sha256=53a7714b7aa17af90e7507d5b5d1a6a20eee5fb078e85131bac19e7ef7abb7b1
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-q17dk0qe/wheels/1e/91/46/0ab326f9e46bc2cc2fe2f35b0e0e6f3b8284d78efd25192d96
#   Building wheel for mecab-ko-dic (pyproject.toml) ... done
#   Created wheel for mecab-ko-dic: filename=mecab_ko_dic-1.0.0-py3-none-any.whl size=33424435 sha256=8e96b7d105d0bea50737fd58cd31ba14372225e199d26cd109cbf3858dbdad86
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-q17dk0qe/wheels/38/b6/bb/e5c73805f8318db251a0a10b4a8becfb4c4e9e49a5b892761a
#   Building wheel for unidic-lite (pyproject.toml) ... done
#   Created wheel for unidic-lite: filename=unidic_lite-1.0.8-py3-none-any.whl size=47658912 sha256=200a0bbd6b6da87e317c438db0c664ecfc904fa21d949bd11bc69e7762a665da
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-q17dk0qe/wheels/5e/1f/0f/4d43887e5476d956fae828ee9b6687becd5544d68b51ed633d
# Successfully built bnnumerizer gruut gruut-ipa gruut_lang_en gruut_lang_de gruut_lang_es gruut_lang_fr mecab-ko-dic unidic-lite
# Installing collected packages: unidic-lite, mecab-ko-dic, jaconv, gruut_lang_fr, gruut_lang_es, gruut_lang_en, gruut_lang_de, bnunicodenormalizer, bnnumerizer, bangla, uroman, python-crfsuite, pysbd, num2words, monotonic-alignment-search, mojimoji, mecab-ko, ko-speech-tools, jsonlines, gruut-ipa, fugashi, coqpit-config, anyascii, spacy-pkuseg, dateparser, cutlet, gruut, coqui-tts-trainer, coqui-tts
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29/29 [coqui-tts]
# Successfully installed anyascii-0.3.3 bangla-0.0.5 bnnumerizer-0.0.2 bnunicodenormalizer-0.1.7 coqpit-config-0.2.4 coqui-tts-0.27.5 coqui-tts-trainer-0.3.3 cutlet-0.5.0 dateparser-1.1.8 fugashi-1.5.2 gruut-2.4.0 gruut-ipa-0.13.0 gruut_lang_de-2.0.1 gruut_lang_en-2.0.1 gruut_lang_es-2.0.1 gruut_lang_fr-2.0.2 jaconv-0.5.0 jsonlines-1.2.0 ko-speech-tools-0.1.0 mecab-ko-1.0.2 mecab-ko-dic-1.0.0 mojimoji-0.0.13 monotonic-alignment-search-0.2.1 num2words-0.5.14 pysbd-0.3.4 python-crfsuite-0.9.12 spacy-pkuseg-1.0.1 unidic-lite-1.0.8 uroman-1.3.1.1
# Processing ./ext/py/num2words
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from num2words==0.5.14) (0.6.2)
# Building wheels for collected packages: num2words
#   Building wheel for num2words (pyproject.toml) ... done
#   Created wheel for num2words: filename=num2words-0.5.14-py3-none-any.whl size=173596 sha256=5b6eb0b2b1b4fe007e9ae0a900a050389bf5414a7a1e0ffa6c3cefade6ae1b6e
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-6xvf01te/wheels/91/c1/9d/969afd2238a0c97ec1ff6138deef111724a8d9a3337bad2424
# Successfully built num2words
# Installing collected packages: num2words
#   Attempting uninstall: num2words
#     Found existing installation: num2words 0.5.14
#     Uninstalling num2words-0.5.14:
#       Successfully uninstalled num2words-0.5.14
# Successfully installed num2words-0.5.14
# Processing ./ext/py/demucs
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dora-search (from demucs==4.1.0)
#   Downloading dora_search-0.1.12.tar.gz (87 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (0.8.2)
# Requirement already satisfied: julius in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (0.2.7)
# Collecting lameenc (from demucs==4.1.0)
#   Downloading lameenc-1.8.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10.0 kB)
# Collecting openunmix (from demucs==4.1.0)
#   Downloading openunmix-1.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (6.0.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (2.10.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (2.10.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (4.67.3)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from dora-search->demucs==4.1.0) (2.3.0)
# Collecting retrying (from dora-search->demucs==4.1.0)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting submitit (from dora-search->demucs==4.1.0)
#   Downloading submitit-1.5.4-py3-none-any.whl.metadata (7.4 kB)
# Collecting treetable (from dora-search->demucs==4.1.0)
#   Downloading treetable-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->demucs==4.1.0) (1.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->demucs==4.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->demucs==4.1.0) (3.0.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->dora-search->demucs==4.1.0) (4.9.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openunmix->demucs==4.1.0) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from submitit->dora-search->demucs==4.1.0) (3.1.2)
# Downloading lameenc-1.8.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (249 kB)
# Downloading openunmix-1.3.0-py3-none-any.whl (40 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading submitit-1.5.4-py3-none-any.whl (76 kB)
# Downloading treetable-0.2.6-py3-none-any.whl (7.4 kB)
# Building wheels for collected packages: demucs, dora-search
#   Building wheel for demucs (pyproject.toml) ... done
#   Created wheel for demucs: filename=demucs-4.1.0-py3-none-any.whl size=76035 sha256=56c447671e2c3259b01b060d921096528bcf961d1ca0c46e70ad3e004ce09d86
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-39bvncqe/wheels/4d/88/27/04af536f68017d4c7c89afad59d5b7b463eb9c7194806fe3e5
#   Building wheel for dora-search (pyproject.toml) ... done
#   Created wheel for dora-search: filename=dora_search-0.1.12-py3-none-any.whl size=75195 sha256=69d74b179bc7495074dd3c13aa18e9e447dad7221e511ef6aac54962d87101c5
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-39bvncqe/wheels/55/40/4c/3478187386b56625ab5aa8a9070ff1eea704ddb27d15abe73f
# Successfully built demucs dora-search
# Installing collected packages: lameenc, treetable, submitit, retrying, dora-search, openunmix, demucs
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [demucs]
# Successfully installed demucs-4.1.0 dora-search-0.1.12 lameenc-1.8.2 openunmix-1.3.0 retrying-1.4.2 submitit-1.5.4 treetable-0.2.6
#
# All required packages are installed.
# UniDic dictionary not found or incomplete. Downloading now…
# download url: https://cotonoha-dic.s3-ap-northeast-1.amazonaws.com/unidic-3.1.0.zip
# Dictionary version: 3.1.0+2021-08-31
# Downloading UniDic v3.1.0+2021-08-31...
# unidic-3.1.0.zip: 100% 526M/526M [00:20<00:00, 26.1MB/s]
# Finished download.
# Downloaded UniDic v3.1.0+2021-08-31 to /usr/local/lib/python3.12/dist-packages/unidic/dicdir
# ---> Hardware detected: {'name': 'cuda', 'os': 'manylinux_2_28', 'arch': 'x86_64', 'pyvenv': [3, 12], 'tag': 'cu128', 'note': ''}
# IPs available for connection:
# ['127.0.0.1', '::1', '172.28.0.12']
# Note: 0.0.0.0 is not the IP to connect. Instead use an IP above to connect and port 7860
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://a888d4ffb28568f28c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Processing eBook file: ilide.info-abdel-fattah-randa-when-michael-met-mina-pr_7f230ddc35153397fb9e97992bc4b741.pdf
# *********** Session: 7c9b501b-167a-4561-8c1a-57fab130793f **************
# In headless mode, store it in case of interruption, crash,
# or reuse of a custom model or custom voice.
# You can resume the conversion with the --session option.
# ************************************************************************
# vram_dict: {'os': 'linux', 'device_type': 'cuda', 'device_name': 'Tesla T4', 'free_bytes': 15527116800, 'total_bytes': 15637086208, 'allocated_bytes': 0, 'reserved_bytes': 0, 'free_vram_gb': 15, 'total_vram_gb': 15, 'allocated_vram_gb': 0, 'reserved_vram_gb': 0}
# Using CUDA
# Free Memory available: 15GB
# File input is a PDF. flatten it in XHTML…
# Running command: /usr/bin/ebook-convert /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/ilide.info-abdel-fattah-randa-when-michael-met-mina-pr_7f230ddc35153397fb9e97992bc4b741.xhtml /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/__ilide.info-abdel-fattah-randa-when-michael-met-mina-pr_7f230ddc35153397fb9e97992bc4b741.epub
# Conversion options changed from defaults:
#   flow_size: 0
#   title: 'When Michael Met Mina'
#   smarten_punctuation: True
#   authors: 'Randa Abdel-Fattah'
#   page_breaks_before: "//*[name()='h1' or name()='h2' or name()='h3' or name()='h4' or name()='h5']"
#   verbose: 1
#   output_profile: 'generic_eink'
#   input_encoding: 'utf-8'
#   disable_font_rescaling: True
#   epub_version: '3'
# 1% Converting input to HTML...
# InputFormatPlugin: HTML Input running
# on /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/ilide.info-abdel-fattah-randa-when-michael-met-mina-pr_7f230ddc35153397fb9e97992bc4b741.xhtml
# Language not specified
# Building file list...
# 	Found files...
# 		 HTMLFile:0:a:'/content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/ilide.info-abdel-fattah-randa-when-michael-met-mina-pr_7f230ddc35153397fb9e97992bc4b741.xhtml'
# Normalizing filename cases
# Rewriting HTML links
# Parsing ilide.info-abdel-fattah-randa-when-michael-met-mina-pr_7f230ddc35153397fb9e97992bc4b741.xhtml ...
# 34% Running transforms on e-book...
# Found image encoded as data URI converting it to normal image
# Found image encoded as data URI converting it to normal image
# Found image encoded as data URI converting it to normal image
# Found image encoded as data URI converting it to normal image
# Found image encoded as data URI converting it to normal image
# Found image encoded as data URI converting it to normal image
# Found image encoded as data URI converting it to normal image
# Merging user specified metadata...
# Detecting structure...
# 	Detected chapter: ‘G’day, John,’ Dad says. ‘Thanks for coming, mate.
# 	Detected chapter: ‘Wasn’t Baba due with the van half an hour ago?’ ‘
# 	Detected chapter: The scholarship had been the idea of my teachers a
# 	Detected chapter: ‘You know, that kind of pressure doesn’t help, Mum
# 	Detected chapter: ‘Obviously not,’ she snaps. Mr Morello reads out a
# 	Detected chapter: ‘Hey.’ I look up. Paula is standing over me, balan
# 	Detected chapter: I grin back at her. ‘Society and Culture.’ ‘Ah, ye
# 	Detected chapter: Paula looks at me, baffled. ‘What’s wrong? Relax.’
# 	Detected chapter: I know that these early days are critical. Mum and
# 	Detected chapter: Clara doesn’t give me a chance to respond. ‘You kn
# 	Detected chapter: I raise an eyebrow sceptically. ‘You might want to
# 	Detected chapter: An angry journalist in Brisbane picks up on the st
# 	Detected chapter: Baba, looking thrilled, is eager for me to see eve
# 	Detected chapter: ‘And we are putting a sign to encourage people to
# 	Detected chapter: Cameron, who’s busy looking through the book tryin
# 	Detected chapter: Michael walks up to me after class. ‘So. Morello c
# 	Detected chapter: We are worlds apart in every sense and I want to k
# ...
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 342
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 343
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 344
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 345
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 346
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 347
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 348
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 349
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 350
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 351
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 352
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 353
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 354
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 355
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 356
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 357
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 358
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 359
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 360
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 361
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 362
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 363
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 364
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 365
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 366
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 367
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 368
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 369
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 370
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 371
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# ----------
# Parsing doc 372
# Parsing xhtml markers…
# Flattening as raw text…
# Converting dates and years to words…
# Convert romans to numbers…
# Convert time to words…
# Convert numbers, maths signs to words…
# Normalize text…
# Get sentences…
# speakers_xtts.pth: 100% 7.75M/7.75M [00:00<00:00, 12.5MB/s]
# Loading TTS xtts-internal model, it takes a while, please be patient…
# config.json: 4.37kB [00:00, 19.5MB/s]
# model.pth: 100% 1.87G/1.87G [00:12<00:00, 151MB/s]
# vocab.json: 361kB [00:00, 46.5MB/s]
# 2026-03-17 13:39:56.299548: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773754796.531715    5203 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773754796.590688    5203 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773754797.021996    5203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773754797.022045    5203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773754797.022050    5203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773754797.022054    5203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-17 13:39:57.063081: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TTS xtts-internal Loaded!
# --------------------------------------------------
# A total of 371 blocks and 6286 sentences.
# --------------------------------------------------
# 0.00%:   0% 0/6286 [00:00<?, ?step/s]Block 0 containing 8 sentences…
# Computing speaker latents…
# /usr/local/lib/python3.12/dist-packages/torchaudio/__init__.py:178: UserWarning: The 'format' parameter is not used by TorchCodec AudioEncoder. Format is determined by the file extension.
#   return save_with_torchcodec(
# 0.02%:   0% 0/6286 [00:07<?, ?step/s] : AboutWhen Michael Met MinaA boy.
# 0.03%:   0% 1/6286 [00:18<13:10:37,  7.55s/step] : A Girl. Two families. One Great Divide. [break]When Michael meets Mina, they are at a rally for refugees, standing on opposite sides.
# 0.05%:   0% 2/6286 [00:25<16:41:35,  9.56s/step] : [break]Mina fled Afghanistan with her mother via a refugee camp, a leaky boat and a detention centre.
# 0.06%:   0% 3/6286 [00:30<14:39:52,  8.40s/step] : [break]Michael's parents have founded a new political party called Aussie Values.
# 0.08%:   0% 4/6286 [00:34<12:01:12,  6.89s/step] : [break]They want to stop the boats.
# 0.08%:   0% 5/6286 [00:34<10:10:27,  5.83s/step]/usr/local/lib/python3.12/dist-packages/torchaudio/__init__.py:178: UserWarning: The 'format' parameter is not used by TorchCodec AudioEncoder. Format is determined by the file extension.
#   return save_with_torchcodec(
# 0.10%:   0% 5/6286 [00:37<10:10:27,  5.83s/step] : [break]Mina wants to stop the hate.
# 0.11%:   0% 6/6286 [00:42<8:41:58,  4.99s/step] : [break]A novel for everyone who wants to fight for love, and against injustice.
# 0.11%:   0% 7/6286 [00:42<8:46:30,  5.03s/step]/usr/local/lib/python3.12/dist-packages/torchaudio/__init__.py:178: UserWarning: The 'format' parameter is not used by TorchCodec AudioEncoder. Format is determined by the file extension.
#   return save_with_torchcodec(
# 0.13%:   0% 7/6286 [00:47<8:46:30,  5.03s/step] : [break]From the bestselling author ofDoes My Head Look Big in This? [pause]
# 0.13%:   0% 8/6286 [00:47<8:57:43,  5.14s/step]End of Block 0
# Combining block 0 to audio, sentence 0 to 7
# Assemble - 100.0%
# Assemble completed!
# Completed → /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/chapters/0.flac
# ********* Combined block audio file saved in /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/chapters/0.flac
# Block 1 containing 2 sentences…
# /usr/local/lib/python3.12/dist-packages/torchaudio/__init__.py:178: UserWarning: The 'format' parameter is not used by TorchCodec AudioEncoder. Format is determined by the file extension.
#   return save_with_torchcodec(
# 0.14%:   0% 8/6286 [00:59<8:57:43,  5.14s/step] : Contents Cover AboutWhen Michael Met MinaDedication Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael
# 0.14%:   0% 9/6286 [00:59<12:27:14,  7.14s/step]/usr/local/lib/python3.12/dist-packages/torchaudio/__init__.py:178: UserWarning: The 'format' parameter is not used by TorchCodec AudioEncoder. Format is determined by the file extension.
#   return save_with_torchcodec(
# 0.16%:   0% 9/6286 [01:09<12:27:14,  7.14s/step] : Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael[pause]
# 0.16%:   0% 10/6286 [01:09<14:00:55,  8.04s/step]End of Block 1
# Combining block 1 to audio, sentence 8 to 9
# Assemble - 100.0%
# Assemble completed!
# Completed → /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/chapters/1.flac
# ********* Combined block audio file saved in /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/chapters/1.flac
# Block 2 containing 2 sentences…
# 0.17%:   0% 10/6286 [01:19<14:00:55,  8.04s/step] : Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina
# 0.19%:   0% 11/6286 [01:27<15:09:07,  8.69s/step] : Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina Michael Mina[pause]
# 0.19%:   0% 12/6286 [01:27<14:54:52,  8.56s/step]End of Block 2
# Combining block 2 to audio, sentence 10 to 11
# Assemble - 100.0%
# Assemble completed!
# Completed → /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/chapters/2.flac
# ********* Combined block audio file saved in /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/chapters/2.flac
# Block 3 containing 1 sentences…
# 0.21%:   0% 12/6286 [01:33<14:54:52,  8.56s/step] : Acknowledgements About Randa Abdel-Fattah Also by Randa Abdel-Fattah Copyright page[pause]
# 0.21%:   0% 13/6286 [01:33<13:33:41,  7.78s/step]End of Block 3
# Combining block 3 to audio, sentence 12 to 12
# Assemble - 100.0%
# Assemble completed!
# Completed → /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/chapters/3.flac
# ********* Combined block audio file saved in /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/chapters/3.flac
# Block 4 containing 1 sentences…
# 0.22%:   0% 13/6286 [01:39<13:33:41,  7.78s/step] : To Deyana, Noor, Adam, and the little one on the way. [pause]
# 0.22%:   0% 14/6286 [01:39<12:36:44,  7.24s/step]End of Block 4
# Combining block 4 to audio, sentence 13 to 13
# Assemble - 100.0%
# Assemble completed!
# Completed → /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/chapters/4.flac
# ********* Combined block audio file saved in /content/ebook2audiobook/tmp/proc-7c9b501b-167a-4561-8c1a-57fab130793f/524dd8f1a47836427d2d0937275f4793/chapters/4.flac
# Block 5 containing 23 sentences…
# 0.24%:   0% 14/6286 [01:43<12:36:44,  7.24s/step] : Michael I know two things for a fact.
# 0.25%:   0% 15/6286 [01:46<10:47:47,  6.20s/step] : [break]My parents are good people.
# 0.27%:   0% 16/6286 [01:52<9:10:34,  5.27s/step] : And ever since I can remember, they've been angry about almost everything.
# 0.29%:   0% 17/6286 [01:56<9:36:00,  5.51s/step] : [break] [break]I scan the area and see my dad,
# 0.30%:   0% 18/6286 [02:04<8:40:45,  4.98s/step] : draped in the Australian flag, talking to Li Chee, who's wearing a flag top hat and holding up aTurn Back the Boatsbanner.
# 0.32%:   0% 19/6286 [02:09<10:06:11,  5.80s/step] : I negotiate my way through the crowd of people and flags on our side,
# 0.33%:   0% 20/6286 [02:13<9:38:48,  5.54s/step] : ignoring the boos and taunts coming from the counter protest.
# 0.35%:   0% 21/6286 [02:20<8:52:09,  5.10s/step] : [break]'Hey, Michael! 'Dad pats me on the back. His forehead is glistening with sweat. 'Really happy you made it.
# 0.37%:   0% 22/6286 [02:23<9:46:02,  5.61s/step] : '[break]'It could be your big moment.
# 0.38%:   0% 23/6286 [02:26<8:26:27,  4.85s/step] : I don't want to miss it.
# 0.40%:   0% 24/6286 [02:29<7:46:01,  4.47s/step] : ''Appreciate it, mate.
# 0.41%:   0% 25/6286 [02:35<6:55:58,  3.99s/step] : 'He takes a deep breath, wipes his forehead with the back of his hand and looks around nervously.
# 0.41%:   0% 26/6286 [02:35<7:51:23,  4.52s/step]
